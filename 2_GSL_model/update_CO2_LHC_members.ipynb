# %% [markdown]
# 这个脚本是把更新后的CO2集合到emul_inputs_SSPxxx.xx.res文件中，确保最后运行的emulator用的是更新后的GSL和CO2

# %%
import numpy as np

scenarios=["natural","SSP119","SSP126","SSP245","SSP370","SSP460","SSP534","SSP585","10000PGC"] 
members=90


# Files read in:
# emul_inputs_SSPxxx.xx.res
# updated_CO2_from_SL_1myr_AP_from500kyrBP.x.res
for mem in range(1,members+1):
# for mem in range(63,65):
    filenameCO2=f"Results/updated_CO2_from_SL_1myr_AP_from500kyrBP.{mem}.res"
    with open(filenameCO2,'r') as f:
        data_CO2=f.readlines()

    for scenario in scenarios[-1:]:
        filename=f"Results/emul_inputs_{scenario}.{mem}.res"
        with open(filename,'r') as f:
            data_orig=f.readlines()
        scenario_line_index = scenarios.index(scenario)+1
        co2_array = np.array([line.strip().split() for line in data_CO2[2:]], dtype=float)
        CO2 = co2_array[:, scenario_line_index]
        
        # Keep header separate and convert only data rows to float
        header = data_orig[0]
        data = np.array([line.strip().split() for line in data_orig[1:]], dtype=float)
        
        # Update CO2 column (first column, index 0)
        # shape check
        print(f'shape of original data: {data.shape}')
        data[:, 0] = CO2
        
        fileout=f"Results/emul_inputs_{scenario}.{mem}.updated.res"
        with open(fileout,'w') as f:
            f.write(header)
            for row in data:
                f.write(' '.join(map(str, row)) + '\n')
        print(f"Written updated file: {fileout}")
# Out:
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.1.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.2.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.3.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.4.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.5.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.6.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.7.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.8.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.9.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.10.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.11.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.12.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.13.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.14.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.15.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.16.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.17.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.18.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.19.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.20.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.21.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.22.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.23.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.24.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.25.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.26.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.27.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.28.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.29.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.30.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.31.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.32.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.33.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.34.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.35.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.36.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.37.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.38.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.39.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.40.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.41.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.42.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.43.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.44.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.45.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.46.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.47.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.48.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.49.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.50.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.51.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.52.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.53.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.54.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.55.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.56.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.57.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.58.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.59.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.60.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.61.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.62.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.63.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.64.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.65.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.66.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.67.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.68.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.69.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.70.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.71.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.72.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.73.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.74.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.75.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.76.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.77.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.78.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.79.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.80.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.81.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.82.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.83.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.84.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.85.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.86.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.87.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.88.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.89.updated.res
# shape of original data: (1001, 5)
# Written updated file: Results/emul_inputs_10000PGC.90.updated.res
